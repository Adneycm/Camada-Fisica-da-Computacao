# %%
import sys
sys.path.append(r'C:\Users\adney\OneDrive - Insper - Institudo de Ensino e Pesquisa\Documentos\Insper\4° semestre - Insper\Camada Física da Computação\Camada-Fisica-da-Computacao\Projeto 7 - dtmf')

from index import Signal
import encode
import decode

# %%
encode.main()
# Out:
# ----- Inicializando encoder -----
#
# Digite um número de entre 0 e 9, ou A, B, C, D, X, #: 8
# O botão '8' possui as seguintes freqências na tabela DTMF: (852, 1339)
#
# Tocando tom referente a tecla '8'

# %%
decode.main()
# Out:
# ----- Inicializando decoder -----
#
# Captura do aúdio irá iniciar em 5 segundos
# Captura do aúdio irá iniciar em 4 segundos
# Captura do aúdio irá iniciar em 3 segundos
# Captura do aúdio irá iniciar em 2 segundos
# Captura do aúdio irá iniciar em 1 segundos
#
# Gravação iniciada
#
# Gravação concluída
#
#
#
#
# [ 2835  3446  3996 14910] 4
#
#
#
# [-20632.14423715 -20327.93171462 -20051.50369486 -14594.458225  ] 4
